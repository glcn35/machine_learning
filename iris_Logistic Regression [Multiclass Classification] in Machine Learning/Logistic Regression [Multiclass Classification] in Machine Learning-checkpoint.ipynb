# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\dincs\Desktop\machine_learning\iriscsv_machine learnig/iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df["variety"].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
df["variety"].replace({'Setosa':"1", 'Versicolor':"2", 'Virginica':"3"},inplace=True)

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split  
#X=df[["sepal.length","sepal.width","petal.length","petal.width"]]
#y=df["variety"]

# %%
X_train,X_test,y_train,y_test=train_test_split(df[["sepal.length","sepal.width","petal.length","petal.width"]],df["variety"],test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
len(X_test)
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array([2, 3, 3, 1, 2, 1, 1, 2, 2, 2, 3, 1, 1, 1, 3, 3, 2, 3, 1, 3, 1, 3,
#        1, 1, 1, 2, 3, 3, 1, 1], dtype=int64)

# %%
X_test #'Setosa':"1", 'Versicolor':"2", 'Virginica':"3"
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 79            5.7          2.6           3.5          1.0
# 134           6.1          2.6           5.6          1.4
# 149           5.9          3.0           5.1          1.8
# 16            5.4          3.9           1.3          0.4
# 61            5.9          3.0           4.2          1.5
# 14            5.8          4.0           1.2          0.2
# 32            5.2          4.1           1.5          0.1
# 106           4.9          2.5           4.5          1.7
# 66            5.6          3.0           4.5          1.5
# 52            6.9          3.1           4.9          1.5
# 123           6.3          2.7           4.9          1.8
# 11            4.8          3.4           1.6          0.2
# 13            4.3          3.0           1.1          0.1
# 7             5.0          3.4           1.5          0.2
# 143           6.8          3.2           5.9          2.3
# 101           5.8          2.7           5.1          1.9
# 69            5.6          2.5           3.9          1.1
# 147           6.5          3.0           5.2          2.0
# 34            4.9          3.1           1.5          0.2
# 148           6.2          3.4           5.4          2.3
# 17            5.1          3.5           1.4          0.3
# 104           6.5          3.0           5.8          2.2
# 47            4.6          3.2           1.4          0.2
# 49            5.0          3.3           1.4          0.2
# 41            4.5          2.3           1.3          0.3
# 75            6.6          3.0           4.4          1.4
# 70            5.9          3.2           4.8          1.8
# 109           7.2          3.6           6.1          2.5
# 48            5.3          3.7           1.5          0.2
# 12            4.8          3.0           1.4          0.1

# %%
lr.score(X_test,y_test)
# Out:
# 0.9333333333333333

# %%
import seaborn as sns

# %%
sns.pairplot(df[["sepal.length","sepal.width","petal.length","petal.width","variety"]],hue="variety")
